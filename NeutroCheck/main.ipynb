# %%
import pandas as pd

# %%
from google.colab import files
data_file = files.upload()
# Out:
#      <input type="file" id="files-f44bd5cc-4eaa-41ef-a701-65383f3acf50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f44bd5cc-4eaa-41ef-a701-65383f3acf50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart.csv

# %%
import io
df = pd.read_csv(io.BytesIO(data_file['heart.csv']))

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# 5   57    1   0       140   192    0  ...      0      0.4      1   0     1       1
# 6   56    0   1       140   294    0  ...      0      1.3      1   0     2       1
# 7   44    1   1       120   263    0  ...      0      0.0      2   0     3       1
# 8   52    1   2       172   199    1  ...      0      0.5      2   0     3       1
# 9   57    1   2       150   168    0  ...      0      1.6      2   0     2       1
#
# [10 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
for column in df.columns:
  print (f"\n\n\nThe column {column} has ")
  print(df[column].value_counts())
# Out:
# The column age has
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 44    11
# 60    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 55     8
# 45     8
# 42     8
# 53     8
# 61     8
# 65     8
# 43     8
# 66     7
# 50     7
# 48     7
# 46     7
# 49     5
# 47     5
# 39     4
# 35     4
# 68     4
# 70     4
# 40     3
# 71     3
# 69     3
# 38     3
# 34     2
# 37     2
# 77     1
# 76     1
# 74     1
# 29     1
# Name: age, dtype: int64
#
#
#
# The column sex has
# 1    207
# 0     96
# Name: sex, dtype: int64
#
#
#
# The column cp has
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64
#
#
#
# The column trestbps has
# 120    37
# 130    36
# 140    32
# 110    19
# 150    17
# 138    13
# 128    12
# 125    11
# 160    11
# 112     9
# 132     8
# 118     7
# 135     6
# 108     6
# 124     6
# 145     5
# 134     5
# 152     5
# 122     4
# 170     4
# 100     4
# 142     3
# 115     3
# 136     3
# 105     3
# ...

# %%
df.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# ## The data seems to be skewed
# ### There are twice as many data points for gender 1 compared to gender 0.

# %%
import matplotlib.pyplot as plt
for cols in df.columns:
  plt.hist(df[cols])
  plt.show()

# %%
import seaborn as sns
from math import corr

# %%
fig=plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
sns.heatmap(df.corr(), annot = True)

# %%
df1 = df[['cp','thalach', 'exang','oldpeak','ca','target']]

# %%
df1.head(20)
# Out:
#     cp  thalach  exang  oldpeak  ca  target
# 0    3      150      0      2.3   0       1
# 1    2      187      0      3.5   0       1
# 2    1      172      0      1.4   0       1
# 3    1      178      0      0.8   0       1
# 4    0      163      1      0.6   0       1
# 5    0      148      0      0.4   0       1
# 6    1      153      0      1.3   0       1
# 7    1      173      0      0.0   0       1
# 8    2      162      0      0.5   0       1
# 9    2      174      0      1.6   0       1
# 10   0      160      0      1.2   0       1
# 11   2      139      0      0.2   0       1
# 12   1      171      0      0.6   0       1
# 13   3      144      1      1.8   0       1
# 14   3      162      0      1.0   0       1
# 15   2      158      0      1.6   0       1
# 16   2      172      0      0.0   0       1
# 17   3      114      0      2.6   0       1
# 18   0      171      0      1.5   0       1
# 19   3      151      0      1.8   2       1
